# %% [markdown]
# <a href="https://colab.research.google.com/github/SaxenaVaishnavi/Machine-Learning-Practices/blob/main/Week_1/Basic_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction on Matpotlib library

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Matplotlib is a powerful and widely-used library in Python for creating static, interactive, and animated visualizations.
#
# This video extensively covers :
#
# - Line Plots
# - Scatter Plots
# - Histogram
# - Bar Chart
# - Pie Chart
# - Box Plot
#
# supplementary content :
#
# - 3D Plotting
# - Animating Plots

# %% [markdown]
# # Line Plots

# %%
# Sample_data_points : (2,1),(5,6),(10,8)
X=[2, 5, 10]
Y=[1, 6, 8]

plt.figure(figsize=(4, 3))              # Setting chart size
plt.plot(X,Y, 'ko--')                   # Creating plot
plt.show()                              # Displaying plot

# %%
# DataSet of a quadratic function y1=x^2
x = [0, 1, 2, 3, 4, 5]
y1 = [0, 1, 4, 9, 16, 25]

# DataSet of a Cubic function y2=x^3
y2=[0, 1, 8, 27, 64, 125]

plt.figure(figsize=(5, 4))

# Create a line plot
plt.plot(x, y1, marker='o', linestyle='--', color='maroon', label='y = x^2')
plt.plot(x, y2, marker='o', linestyle='--', color='olive', label='y = x^3')

# Labels and a title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot')

plt.legend()                         # Add a legend
plt.grid(True, c='cadetblue')        # Add gridlines
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
# Random generation of Data
x=np.random.randint(100,size=100)
y=np.random.randint(100,size=100)

# Creating a Scatter plot
plt.figure(figsize=(5, 4))
plt.scatter(x,y, marker='.', c='maroon', s=50, alpha=0.7)

#Add labels and Title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# # Histogram

# %%
# Random normal distribution with mean=20 and Std=5
x = np.random.normal(20, 5, 1000)

# Plotting the histogram
plt.figure(figsize=(5, 4))
plt.hist(x, bins=10, color='maroon')

# Add title
plt.title('Histogram',fontsize=25)
plt.show()

# %% [markdown]
# # Bar Chart

# %%
# Sample data
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(100, size=5)

# Create a bar chart
plt.figure(figsize=(5, 4))
plt.bar(categories, values, color='maroon', width=0.7)

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart')
plt.show()

# %% [markdown]
# # Pie chart

# %%
# Sample data
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(100, size=5)

# Create a Pie chart
plt.figure(figsize=(7, 6))
plt.pie(values, labels=categories,
        explode=[0,0.1,0,0,0],
        autopct="%.1f%%",
        startangle=90)

# Add Title
plt.title('Bar Chart')
plt.show()

# %% [markdown]
# # Box Plot

# %%
# Sample data
x=np.random.normal(200, 8, 1000)

#Five Number summary
IQR = np.quantile(x, 0.75) - np.quantile(x, 0.25)
print('Lower Fence : ', np.quantile(x, 0.25)-(1.5*IQR))
print('Q1 : ', np.quantile(x, 0.25))
print('Median : ', np.median(x))
print('Q3 : ', np.quantile(x, 0.75))
print('Upper Fence : ', np.quantile(x, 0.75)+(1.5*IQR))
print('\n')

# Create a Pie chart
plt.figure(figsize=(5, 4))
plt.boxplot(x)

# Add Title
plt.title('BOX Plot')
plt.yticks([np.quantile(x, 0.25)-(1.5*IQR),
            np.quantile(x, 0.25),
            np.median(x),
            np.quantile(x, 0.75),
            np.quantile(x, 0.75)+(1.5*IQR)])
plt.show()
# Out:
# Lower Fence :  180.19572632611926
# Q1 :  195.30473777543602
# Median :  200.1893970522881
# Q3 :  205.37741207498053
# Upper Fence :  220.48642352429727

# %% [markdown]
# # Subploting

# %%
#Creating the dataset
x = np.arange(100)

P1 = np.sin(x)
P2 = np.cos(x)

#1st subplot
plt.subplot(221)
plt.plot(P1)
plt.title('sine function')

#2nd Subplot
plt.subplot(222)
plt.plot(P2)
plt.title('cosine function')

plt.show()

# %%
# Spliting the figure into subparts
fig , axis = plt.subplots(2,2)

# Plotting through axis
axis[0, 0].plot(np.sin(np.arange(100)))
axis[0, 1].hist(np.random.normal(20,5,1000))
axis[1, 0].bar(categories, values)
axis[1, 1].plot(np.log(np.arange(100)))

# Display the plots
plt.show()
# Out:
# <ipython-input-105-f7b0ced88f4b>:8: RuntimeWarning: divide by zero encountered in log
#   axis[1, 1].plot(np.log(np.arange(100)))

# %% [markdown]
# # 3D PLOTTING

# %%
# Defining the axis as 3D
ax = plt.axes(projection='3d')

# Dataset generation
X = np.random.randint(100, size = 100)
Y = np.random.randint(100, size = 100)
Z = np.random.randint(100, size = 100)

# Plotting the dataset
ax.scatter(X,Y,Z)

# Display the plot
plt.show()
